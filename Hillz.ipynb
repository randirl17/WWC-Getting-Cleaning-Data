# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import nltk
import wordcloud as wc

# %matplotlib inline

# %%
#corpus=body of text, lexicon=connotation dependent on context, token=chunks of body of text
#rule of thumb:  if a column has >30% NaNs it will not return useful info

# %%
df = pd.read_csv('./output/Emails.csv')

# %%
df.head()
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#      MetadataTo       MetadataFrom  SenderPersonId           MetadataDateSent  \
# 0             H  Sullivan, Jacob J              87  2012-09-12T04:00:00+00:00
# 1             H                NaN             NaN  2011-03-03T05:00:00+00:00
# 2            ;H    Mills, Cheryl D              32  2012-09-12T04:00:00+00:00
# 3             H    Mills, Cheryl D              32  2012-09-12T04:00:00+00:00
# 4  Abedin, Huma                  H              80  2011-03-11T05:00:00+00:00
#
#         MetadataDateReleased  \
# 0  2015-05-22T04:00:00+00:00
# ...

# %%
df.tail()
# Out:
#         Id  DocNumber             MetadataSubject MetadataTo  \
# 7940  7941  C05778462                       WYDEN          H
# 7941  7942  C05778463                      SENATE          H
# 7942  7943  C05778465               RICHARD (TNR)          H
# 7943  7944  C05778466                       FROM           H
# 7944  7945  C05778470  NOTE FOR SECRETARY CLINTON          H
#
#            MetadataFrom  SenderPersonId           MetadataDateSent  \
# 7940   Verma, Richard R             180  2010-12-16T05:00:00+00:00
# 7941   Verma, Richard R             180  2010-12-16T05:00:00+00:00
# 7942   Jiloty, Lauren C             116  2010-12-16T05:00:00+00:00
# 7943           PVerveer             143  2012-12-17T05:00:00+00:00
# 7944  Sullivan, Jacob J              87  2010-12-17T05:00:00+00:00
#
#            MetadataDateReleased  \
# 7940  2015-08-31T04:00:00+00:00
# 7941  2015-08-31T04:00:00+00:00
# 7942  2015-08-31T04:00:00+00:00
# 7943  2015-08-31T04:00:00+00:00
# ...

# %%
df.columns
# Out:
# Index(['Id', 'DocNumber', 'MetadataSubject', 'MetadataTo', 'MetadataFrom',
#        'SenderPersonId', 'MetadataDateSent', 'MetadataDateReleased',
#        'MetadataPdfLink', 'MetadataCaseNumber', 'MetadataDocumentClass',
#        'ExtractedSubject', 'ExtractedTo', 'ExtractedFrom', 'ExtractedCc',
#        'ExtractedDateSent', 'ExtractedCaseNumber', 'ExtractedDocNumber',
#        'ExtractedDateReleased', 'ExtractedReleaseInPartOrFull',
#        'ExtractedBodyText', 'RawText'],
#       dtype='object')

# %%
cols = ['Id','DocNum','MSubj','MTo','MFrom','SenderID','MSent','MRelease','Mpdf','MCase','MDocClass','ExSubj','ExTo','ExFrom','ExCC','ExSent','ExCase','']

# %%
df.MetadataSubject[:20]
# Out:
# 0                                                   WOW
# 1     H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2                                         CHRIS STEVENS
# 3                            CAIRO CONDEMNATION - FINAL
# 4     H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 5     MEET THE RIGHT-WING EXTREMIST BEHIND ANTI-MUSL...
# 6     ANTI-MUSLIM FILM DIRECTOR IN HIDING, FOLLOWING...
# 7     H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 8                                   SECRETARY'S REMARKS
# 9                                         MORE ON LIBYA
# 10               ABZ AN HBJ ON LIBYA AND WEST BANK/GAZA
# 11                                        MORE ON LIBYA
# 12                                                  HEY
# 13    PIECE ON LIBYA NFZ THAT WILL APPEAR ON NYT OP-...
# 14                                 NOT A DRY EYE IN NEA
# 15                                            THANK YOU
# 16                                   THE YOUTH OF LIBYA
# ...

# %%
#nltk hapaxis
